# %%
import pandas as pd
import numpy as np
from collections import defaultdict, Counter
import glob
import json
from random import sample
import sklearn
import re
import string
import warnings
from bs4 import BeautifulSoup
import gensim
from gensim.models.phrases import Phrases
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from analysis_func.text_preproc import preproc_text
from analysis_func.topic_preproc import prepare_corp
from analysis_func.topic_model import topicmodel
from analysis_func.saveload_topicmodels import save_modelanddata, load_modelanddata
import datetime
import os
import time
import sys


from pandarallel import pandarallel
pandarallel.initialize()
# Out:
# INFO: Pandarallel will run on 128 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
data = pd.read_csv("/data/shruti/ONR/small_data/Twitter_text/twitter_text_bjp_inc_withRT.csv", header=0)
data.head()
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (0,1,2,3,4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Unnamed: 0 screen_name                                               text  \
# 0          0         NaN   @umashankarsingh मतलब पुतिन पर भी पनौती चढ़ गयी।
# 1          1         NaN  @sambitswaraj @BJP4India @PMOIndia मतलब जो कां...
# 2          2         NaN  @myogiadityanath शायद इसीलिए आपने राम मंदिर ट्...
# 3          3         NaN  @dmbas_ के आदेश के बावजूद DSO द्वारा कोई कार्य...
# 4          4         NaN  भारत को जिहादी राष्ट्र बताने वाली देशद्रोही #क...
#
#   party language                                                url  is_RT
# 0   INC       hi                                                NaN    NaN
# 1   INC       hi                                                NaN    NaN
# 2   INC       hi                                                NaN    NaN
# 3   INC       hi  https://twitter.com/Thakur_deepak_s/status/146...    NaN
# 4   INC       hi                                                NaN    NaN

# %%
len(data)
# Out:
# 25828521

# %%
len(data.dropna(subset=['screen_name']))
# Out:
# 20857064

# %%
len(data.dropna(subset=['url']))
# Out:
# 5275905

# %%
from tld import get_tld

# %%
def get_domain(link):
    try:
        res = get_tld(link, as_object=True)
        return res.fld
    except:
        fakevar=1


data['domain'] = data['url'].parallel_apply(lambda x: get_domain(x))

# %%
data.head()
# Out:
#   Unnamed: 0 screen_name                                               text  \
# 0          0         NaN   @umashankarsingh मतलब पुतिन पर भी पनौती चढ़ गयी।
# 1          1         NaN  @sambitswaraj @BJP4India @PMOIndia मतलब जो कां...
# 2          2         NaN  @myogiadityanath शायद इसीलिए आपने राम मंदिर ट्...
# 3          3         NaN  @dmbas_ के आदेश के बावजूद DSO द्वारा कोई कार्य...
# 4          4         NaN  भारत को जिहादी राष्ट्र बताने वाली देशद्रोही #क...
#
#   party language                                                url  is_RT  \
# 0   INC       hi                                                NaN    NaN
# 1   INC       hi                                                NaN    NaN
# 2   INC       hi                                                NaN    NaN
# 3   INC       hi  https://twitter.com/Thakur_deepak_s/status/146...    NaN
# 4   INC       hi                                                NaN    NaN
#
#         domain
# 0         None
# 1         None
# 2         None
# 3  twitter.com
# 4         None

# %%
common_domains = ['twitter.com', 'facebook.com', 'google.com', 'm.tech', 'm.sc', 'b.tech', 'page.link', 'youtu.be', 'bit.ly', 'instagram.com','youtube.com']

filtered_link = data.loc[~data['domain'].isin(common_domains)]

# %%
filtered_link.head()
# Out:
#   Unnamed: 0 screen_name                                               text  \
# 0          0         NaN   @umashankarsingh मतलब पुतिन पर भी पनौती चढ़ गयी।
# 1          1         NaN  @sambitswaraj @BJP4India @PMOIndia मतलब जो कां...
# 2          2         NaN  @myogiadityanath शायद इसीलिए आपने राम मंदिर ट्...
# 4          4         NaN  भारत को जिहादी राष्ट्र बताने वाली देशद्रोही #क...
# 5          5         NaN  मंगल पांडेय, चंद्रशेखर आज़ाद, भगत सिंह, सुखदेव...
#
#   party language  url  is_RT domain
# 0   INC       hi  NaN    NaN   None
# 1   INC       hi  NaN    NaN   None
# 2   INC       hi  NaN    NaN   None
# 4   INC       hi  NaN    NaN   None
# 5   INC       hi  NaN    NaN   None

# %%
filtered_link = filtered_link.dropna(subset=['domain'])

# %%
filtered_link.head()
# Out:
#     Unnamed: 0      screen_name  \
# 16          16              NaN
# 139        139  Thakur_deepak_s
# 141        141  Thakur_deepak_s
# 190        190  Thakur_deepak_s
# 216        216  Thakur_deepak_s
#
#                                                   text party language  \
# 16   दुनिया की पहली पार्टी है ये जो इस हद तक गिरी ह...   INC       hi
# 139  @myogiadityanath आपकी ऐसी गैर जिम्मेदाराना हरक...   INC       hi
# 141  @narendramodi आपने कहा था कि देश नबी झुकने दूं...   INC       hi
# 190  This is absolutely unacceptable. A bloody repo...   INC       en
# 216  @sambitswaraj What about dis?\nhttps://t.co/mx...   INC       en
#
#                                                    url  is_RT  \
# 16   https://www.bhaskar.com/local/maharashtra/news...    NaN
# 139  https://navbharattimes.indiatimes.com/metro/lu...    NaN
# 141  https://indianexpress.com/article/india/global...    NaN
# 190  https://thelogicalindian.com/trending/arnab-go...    NaN
# 216  https://timesofindia.indiatimes.com/city/hubba...    NaN
#
#                    domain
# 16            bhaskar.com
# 139        indiatimes.com
# 141     indianexpress.com
# 190  thelogicalindian.com
# 216        indiatimes.com

# %%
news_domains = pd.read_csv("../lite_data/domaintitles_annotated_no_international.csv", header=0)
news_domains.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         domain  \
# 0           0             0  indiatoday.in
# 1           1             3  prajavani.net
# 2           2             4   thehindu.com
# 3           3             6    abplive.com
# 4           4             8     news18.com
#
#                                           title_text  is_news  \
# 0  Latest News, Breaking News Today - Bollywood, ...      1.0
# 1  Prajavani | ಪ್ರಜಾವಾಣಿ ತಾಜಾ ಸುದ್ದಿ, ಸಮಾಚಾರ, ವಾರ...      1.0
# 2  \nThe Hindu: Breaking News, India News, Sports...      1.0
# 3  Hindi News, Breaking News in Hindi, हिंदी न्यू...      1.0
# 4  News, Breaking News, Latest News, News Headlin...      1.0
#
#                                            titleDEsc international  \
# 0  indiatoday.in\nLatest News, Breaking News Toda...      domestic
# 1  prajavani.net\nPrajavani | ಪ್ರಜಾವಾಣಿ ತಾಜಾ ಸುದ್...      domestic
# 2  thehindu.com\n\nThe Hindu: Breaking News, Indi...      domestic
# 3  abplive.com\nHindi News, Breaking News in Hind...      domestic
# 4  news18.com\nNews, Breaking News, Latest News, ...      domestic
#
#    if_annotated_international
# 0                        True
# 1                        True
# 2                        True
# 3                        True
# 4                        True

# %%
newslist = news_domains.loc[news_domains['international']=='domestic']['domain'].tolist()

# %%
filtered_link = filtered_link.loc[filtered_link['domain'].isin(newslist)]
filtered_link.head()
# Out:
#     Unnamed: 0      screen_name  \
# 16          16              NaN
# 139        139  Thakur_deepak_s
# 141        141  Thakur_deepak_s
# 216        216  Thakur_deepak_s
# 218        218  Thakur_deepak_s
#
#                                                   text party language  \
# 16   दुनिया की पहली पार्टी है ये जो इस हद तक गिरी ह...   INC       hi
# 139  @myogiadityanath आपकी ऐसी गैर जिम्मेदाराना हरक...   INC       hi
# 141  @narendramodi आपने कहा था कि देश नबी झुकने दूं...   INC       hi
# 216  @sambitswaraj What about dis?\nhttps://t.co/mx...   INC       en
# 218  Does any media channel has d courage to show d...   INC       en
#
#                                                    url  is_RT  \
# 16   https://www.bhaskar.com/local/maharashtra/news...    NaN
# 139  https://navbharattimes.indiatimes.com/metro/lu...    NaN
# 141  https://indianexpress.com/article/india/global...    NaN
# 216  https://timesofindia.indiatimes.com/city/hubba...    NaN
# 218  https://timesofindia.indiatimes.com/city/hubba...    NaN
#
#                 domain
# 16         bhaskar.com
# 139     indiatimes.com
# 141  indianexpress.com
# 216     indiatimes.com
# 218     indiatimes.com

# %%
#text preproessing - filter engligh, hindi, marathi stop words, remove puncts, hash, mentions, urls, weird spaces etc.
filtered_link['clean_text'] = filtered_link['text'].parallel_apply(lambda x: preproc_text(x))

# %%
filtered_link.head()
# Out:
#     Unnamed: 0      screen_name  \
# 16          16              NaN
# 139        139  Thakur_deepak_s
# 141        141  Thakur_deepak_s
# 216        216  Thakur_deepak_s
# 218        218  Thakur_deepak_s
#
#                                                   text party language  \
# 16   दुनिया की पहली पार्टी है ये जो इस हद तक गिरी ह...   INC       hi
# 139  @myogiadityanath आपकी ऐसी गैर जिम्मेदाराना हरक...   INC       hi
# 141  @narendramodi आपने कहा था कि देश नबी झुकने दूं...   INC       hi
# 216  @sambitswaraj What about dis?\nhttps://t.co/mx...   INC       en
# 218  Does any media channel has d courage to show d...   INC       en
#
#                                                    url  is_RT  \
# 16   https://www.bhaskar.com/local/maharashtra/news...    NaN
# 139  https://navbharattimes.indiatimes.com/metro/lu...    NaN
# 141  https://indianexpress.com/article/india/global...    NaN
# 216  https://timesofindia.indiatimes.com/city/hubba...    NaN
# 218  https://timesofindia.indiatimes.com/city/hubba...    NaN
#
#                 domain                                         clean_text
# 16         bhaskar.com  दुनिया पहली हद गिरी घटिया भरी सब बढ़कर चोर मक्...
# 139     indiatimes.com  आपकी ऐसी गैर जिम्मेदाराना हरकतें पूरे उत्तर शर...
# 141  indianexpress.com         आपने नबी झुकने दूंगा आपने कलंकित कसर छोड़ी
# 216     indiatimes.com                                                dis
# 218     indiatimes.com  media channel courage dis isnt dis news runnin...

# %%
import re
import string
import warnings
from bs4 import BeautifulSoup
#from markdown import markdown

emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U0001F1F2-\U0001F1F4"  # Macau flag
        u"\U0001F1E6-\U0001F1FF"  # flags
        u"\U0001F600-\U0001F64F"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U0001F1F2"
        u"\U0001F1F4"
        u"\U0001F620"
        u"\u200d"
        u"\u2640-\u2642"
        "]+", flags=re.UNICODE)

#text = emoji_pattern.sub(r'', text)


remove_urls = lambda x: re.sub("http(.+)?(\W|$)", ' ', x)
remove_RT = lambda x: x.replace("RT ", "")
remove_mentions = lambda x: re.sub("@\S+", '', x)
remove_hashtags = lambda x: re.sub("#\S+", '', x)
remove_digits = lambda x: re.sub("\d+", "", x)
remove_punct = lambda x: re.sub("!|\||\%|\.|\-|\/|:|…|,|\?|।+", "", x)
remove_emojis = lambda x: emoji_pattern.sub("", x)
normalize_spaces = lambda x: re.sub("[\n\r\t ]+", ' ', x)
remove_stop = lambda x: " ".join(i for i in x.lower().split() if i not in stopwords)

# %%
len(filtered_link)
# Out:
# 97694

# %% [markdown]
# ## extract phrases

# %%
print("prepping corpus for topicmodel")
# prepare data for topic modeling
corp = filtered_link['clean_text'].tolist()
parties = filtered_link['party'].tolist()
corp_tokens = [c.split() for c in corp]
phrases = Phrases(corp_tokens, min_count=10, threshold=0.1)
tokes = [phrases[t] for t in corp_tokens]
print(len(filtered_link), len(corp_tokens), len(tokes))
# Out:
# prepping corpus for topicmodel
# 97694 97694 97694

# %%
print(corp_tokens[250], tokes[250])
# Out:
# ['कैसे', 'अच्छे', 'आमजन', 'जेब', 'काटो', 'कारोबार', 'बर्बाद', 'करो'] ['कैसे_अच्छे', 'आमजन_जेब', 'काटो_कारोबार', 'बर्बाद_करो']

# %%
domain_dict = defaultdict(list)
i=0
for idx, row in filtered_link.iterrows():
    dom = row['domain']
    domain_dict[dom] = domain_dict[dom] + tokes[i]
    i = i+1

# %%
domain_dict.keys()
# Out:
# dict_keys(['bhaskar.com', 'indiatimes.com', 'indianexpress.com', 'livemint.com', 'patrika.com', 'altnews.in', 'oneindia.com', 'indiatoday.in', 'outlookindia.com', 'npg.news', 'lalluram.com', 'ibc24.in', 'thewirehindi.com', 'aajtak.in', 'ndtv.com', 'firstpost.com', 'economictimes.com', 'timesofindia.com', 'businessinsider.in', 'republicworld.com', 'eurasiantimes.com', 'opindia.com', 'india.com', 'kashmirobserver.net', 'aninews.in', 'sundayguardianlive.com', 'news18.com', 'jagran.com', 'etvbharat.com', 'thedailyguardian.com', 'dailyo.in', 'newsnationtv.com', 'tribuneindia.com', 'tv9hindi.com', 'abplive.com', 'theprint.in', 'news9live.com', 'greaterkashmir.com', 'crosstownnews.in', 'theweek.in', 'telegraphindia.com', 'rajyasameeksha.com', 'thewire.in', 'thehindubusinessline.com', 'carandbike.com', 'thelallantop.com', 'thehindu.com', 'scroll.in', 'barandbench.com', 'thequint.com', 'japantimes.co.jp', 'sentinelassam.com', 'nationalheraldindia.com', 'deccanherald.com', 'freepressjournal.in', 'livelaw.in', 'lokmat.com', 'punchnamu.com', 'indiatvnews.com', 'ndtv.in', 'devdiscourse.com', 'timesnownews.com', 'newslaundry.com', 'humsamvet.com', 'punjabkesari.com', 'tv9bharatvarsh.com', 'punjabkesari.in', 'navjivanindia.com', 'amarujala.com', 'enavabharat.com', 'sudarshannews.in', 'doonhorizon.in', 'naidunia.com', 'loksatta.com', 'tv9marathi.com', 'timesnowhindi.com', 'newstrack.com', 'trunicle.com', 'businesstoday.in', 'dailypioneer.com', 'udayavani.com', 'uniindia.com', 'prajavani.net', 'thenewsminute.com', 'thebetterindia.com', 'tv9kannada.com', 'thebridge.in', 'dnaindia.com', 'vijaykarnataka.com', 'wionews.com', 'asianetnews.com', 'business-standard.com', 'indianarrative.com', 'kalaignarseithigal.com', 'news7tamil.live', 'esakal.com', 'hindutamil.in', 'forbesindia.com', 'jaihindtv.in', 'satyahindi.com', 'nayaindia.com', 'onmanorama.com', 'newsclick.in', 'prabhatkhabar.com', 'newswing.com', 'sharpbharat.com', 'hindikhabar.com', 'nakkheeran.in', 'newsonair.com', 'mynation.com', 'businessworld.in', 'firstindianews.com', 'newsdanka.com', 'vikatan.com', 'organiser.org', 'panchjanya.com', 'polimernews.com', 'thefocusindia.com', 'sarkarnama.in', 'latestly.com', 'newsijt.com', 'indiatv.in', 'nationnews.in', 'dinamalar.com', 'downtoearth.org.in', 'prabhasakshi.com', 'siasat.com', 'udupitimes.com', 'mumbaitak.in', 'newsbharati.com', 'cnbctv18.com', 'heraldgoa.in', 'jantakiawaz.org', 'maalaimalar.com', 'navodayatimes.in', 'forceindia.net', 'zeebiz.com', 'medicaldialogues.in', 'clarionindia.net', 'youthkiawaaz.com', 'abpnadu.com', 'dailythanthi.com', 'dinamani.com', 'maharashtratimes.com', 'manoramanews.com', 'deccanchronicle.com', 'socialnews.xyz', 'kathir.news', 'dinakaran.com', 'telanganatoday.com', 'dishadaily.com', 'lokshahi.live', 'ibtimes.co.in', 'circle.page', 'mathrubhumi.com', 'newskranti.com', 'thodkyaat.com', 'mid-day.com', 'sandeshnews.tv', 'trishulnews.com', 'upuklive.com', 'tarunmitra.in', 'navshaktinews.com', 'ichowk.in', 'sanjeevnitoday.com', 'swadeshnews.in', 'jantaserishta.com', 'daijiworld.com', 'newsroompost.com', 'thehansindia.com', 'hwnews.in', 'mpbreakingnews.in', 'tolivelugu.com', 'eenadu.net', 'haribhoomi.com', 'sabrangindia.in', 'bihardootnews.com', 'ptcnews.tv', 'nenow.in', 'newindian.in', 'gstv.in', 'kanaknews.com', 'odishatv.in', 'orissapost.com', 'pardaphash.com', 'policenama.com', 'pudhari.news', 'samayam.com', 'newsmobile.in', 'realreport.in', 'prameyanews7.com', 'prameya.com', 'newsfirstlive.com', 'jaimaharashtranews.com', 'indiadarpanlive.com', 'keralakaumudi.com', 'mediavigil.com', 'gaurilankeshnews.com', 'news4nation.com', 'punekarnews.in', 'sandesh.com', 'tfipost.com', 'anewsoffice.com', 'divyabhaskar.co.in', 'eastmojo.com', 'glibs.in', 'asomiyapratidin.in', 'theshillongtimes.com', 'newstracklive.com', 'chitralekha.com', 'outlookhindi.com', 'firstbihar.com', 'arunchol.com', 'saamtv.com', 'enewsinsight.com', 'odishareporter.in', 'sify.com', 'newsmeter.in', 'agniban.com', 'newslivetv.com', 'tricitytoday.com', ' ...

# %%
keywords2domain = defaultdict(list)
for d in domain_dict.keys():
    for kwrd in domain_dict[d]:
        keywords2domain[kwrd].append(d)

# %%
domain_dict['ichowk.in']
# Out:
# ['पाकिस्तान',
#  'इमरान',
#  'खान',
#  'बस',
#  'चले',
#  'भारतइजरायल',
#  'संबंधों',
#  'खराब',
#  'मौका',
#  'चूकें',
#  'दोनों',
#  'देशों',
#  'मजबूत',
#  'संबंधों',
#  'मेरे',
#  'आलेख',
#  'न्यूज_कवरेज',
#  'आई',
#  'चौक',
#  'सबों',
#  'समक्ष',
#  'शाहरुख',
#  'खान',
#  'पत्नी',
#  'गौरी',
#  'खान',
#  'बेटे',
#  'आर्यन_खान',
#  'लालनपालन',
#  'सही',
#  'ताकि',
#  'बेहतर',
#  'नागरिक',
#  'बन',
#  'उभरे',
#  'इतनी',
#  'भर',
#  'उम्मीद',
#  'जरूर',
#  'कानून',
#  'देंगे',
#  'तालिबानी',
#  'लड़ाकों',
#  'अफगानिस्तान',
#  'कब्जा',
#  'लिया',
#  'इस्लामिक',
#  'मुल्कों',
#  'दिए',
#  'खादपानी',
#  'उपज',
#  'तालिबान',
#  'वर्तमान',
#  'समय',
#  'अफगानिस्तान',
#  'स्थिति',
#  'बदतर',
#  'दी',
#  'महिला',
#  'पुरुष',
#  'हॉकी',
#  'टीमों',
#  'टोक्यो_ओलंपिक',
#  'खेलों',
#  'चमत्कारी',
#  'प्रदर्शन',
#  'गर्व',
#  'महसूस',
#  'दोनों',
#  'टीमों',
#  'अधिकतर',
#  'खिलाड़ियों',
#  'जिनका',
#  'संबंध',
#  'छोटेछोटे',
#  'शहरों',
#  'कस्बों',
#  'गांवों',
#  'कमाल',
#  'दिखाया',
#  'सरकारों',
#  'संकटकाल',
#  'आरोपप्रत्यारोप',
#  'समय',
#  'गंवाए',
#  'बिना',
#  'कारगर',
#  'स्वास्थ्य',
#  'सेवाएं',
#  'उपलब्ध',
#  'करवाने',
#  'चाहिए',
#  'गांधीनेहरू',
#  'परिवार',
#  'बिल्कुल',
#  'अलग',
#  'दामाद',
#  'आए',
#  'रॉबर्ट',
#  'वाड्रा',
#  'जिनपर',
#  'काले',
#  'कारनामों',
#  'आरोप',
#  'लगते',
#  'दूसरी_तरफ',
#  'फिरोज',
#  'गांधी',
#  'भ्रष्टाचार',
#  'खिलाफ',
#  'हमेशा',
#  'आवाज_बुलंद',
#  'राहुल_गांधी',
#  'दादी',
#  'श्रीमती',
#  'इंदिरा_गांधी',
#  'सन',
#  'लगाई',
#  'इमरजेंसी',
#  'अंततः',
#  'गलत',
#  'बताया',
#  'आखिर',
#  'नेहरूगाँधी',
#  'खानदान',
#  'जाने_कितने',
#  'गुनाहों',
#  'माफी',
#  'मांगनी',
#  'क्रिकेट',
#  'बिग',
#  'मैच',
#  'प्लेयर',
#  'चमत्कारी',
#  'प्रतिभा',
#  'मैंने',
#  'परख',
#  'लिया',
#  'तभी',
#  'मैंने',
#  'विद्यालय',
#  'टूर्नामेंट',
#  'खेलने',
#  'बुलाया',
#  'पंत',
#  'धमाकेदार',
#  'बैटिंग',
#  'सबको',
#  'प्रभावित',
#  'चुके',
#  'आर्थिक',
#  'राजधानी',
#  'मास्क',
#  'पहने',
#  'लोग',
#  'गिनती',
#  'दिखाई',
#  'देते',
#  'जुहू',
#  'बीच',
#  'मस्ती',
#  'आने',
#  'सैकड़ों',
#  'लोग',
#  'सामाजिक',
#  'दूरी',
#  'बना',
#  'चल',
#  'मास्क',
#  'पहन',
#  'राज्यसभा',
#  'विदाई',
#  'भाषण',
#  'गुलाम',
#  'नबी',
#  'आजाद',
#  '‘मुझे',
#  'फक्र',
#  'हिंदुस्तानी',
#  'मुसलमान',
#  'हूं’',
#  'बयान',
#  'उन्होंने',
#  'उपराष्ट्रपति',
#  'हामिद',
#  'अंसारी',
#  'आईना',
#  'दिख',
#  'दुर्भाग्य',
#  'पाकिस्तान',
#  'पड़ोसी',
#  'रूप',
#  'बीते',
#  'मंगलवार',
#  'ईरान',
#  'पाकिस्तान',
#  'सर्जिकल_स्ट्राइक',
#  'अपहृत',
#  'नागरिकों',
#  '“जैश',
#  'उल',
#  'अदल”',
#  'आतंकी',
#  'संगठन',
#  'कब्जे',
#  'छुड़वा',
#  'शिक्षा',
#  'साहित्य',
#  'कला',
#  'संस्कृति',
#  'राजनीति',
#  'खेल',
#  'समाज',
#  'क्षेत्र',
#  'ऐसा',
#  'भेदभाव',
#  'भेदभाव',
#  'शिकार',
#  'शिकारी',
#  'समाज',
#  'समाज',
#  'आधुनिक',
#  'जाए',
#  'धर्म',
#  'जाति',
#  'सामाजिक',
#  'नजरिया',
#  'कभी',
#  'बदल',
#  '#',
#  'अखिल',
#  'बेवड़ा',
#  'संघ',
#  'सिफ़ारिश',
#  'मैंने',
#  'लेख',
#  'लिखा',
#  'प्रकार',
#  'दबाव',
#  'बनाएँ',
#  'बैकिंग',
#  'लम्बी',
#  'समय',
#  'मिले',
#  'पढ़िए',
#  'बिहार',
#  'महागठबंधन',
#  'हार',
#  'वजहें',
#  'जाति',
#  'धर्म',
#  'बिहार',
#  'महागठबंधन',
#  'हार',
#  'वजहें',
#  'जाति',
#  'धर्म',
#  'संकट',
#  'घड़ी',
#  'मुखिया',
#  'फ़र्ज़',
#  'निभाएँ',
#  'गंगाजल',
#  'वादा',
#  'निभाएं',
#  'राजस्थान',
#  'पंजाब',
#  'गहलोत',
#  'अमरिंदर',
#  'दंगा',
#  'केस',
#  'केजरीवाल',
#  'अमित_शाह',
#  'आगे',
#  'अग्रिम',
#  'सरेंडर',
#  'सचिन_पायलट',
#  'प्रियंका_गांधी',
#  'मान',
#  'गहलोत',
#  'बुजुर्ग',
#  'डरते',
#  'प्रियंका_गांधी',
#  'बनने',
#  'रंगीला',
#  'शाह',
#  'रास्ते',
#  'चल',
#  'आलाकमान',
#  'कैसे',
#  'बचेगी',
#  'दंगा',
#  'केस',
#  'केजरीवाल',
#  'अमित_शाह',
#  'आगे',
#  'अग्रिम',
#  'सरेंडर',
#  'read_article',
#  'lord_ram',
#  'ingrained',
#  'heart',
#  'minds',
#  'millions',
#  'hindus',
#  'play',
#  'hindu',
#  'sentiments',
#  'बिहार',
#  'महागठबंधन',
#  'हार',
#  'वजहें',
#  'जाति',
#  'धर्म',
#  'डर',
#  '“कौन',
#  'वो”',
#  'चुनाव',
#  'टलने',
#  'इनसाईड',
#  'स्टोरी']

# %%
keywords2domain['पाकिस्तान']
# Out:
# ['bhaskar.com',
#  'bhaskar.com',
#  'bhaskar.com',
#  'bhaskar.com',
#  'bhaskar.com',
#  'bhaskar.com',
#  'indiatimes.com',
#  'indiatimes.com',
#  'indiatimes.com',
#  'indiatimes.com',
#  'indianexpress.com',
#  'indianexpress.com',
#  'indianexpress.com',
#  'indianexpress.com',
#  'patrika.com',
#  'altnews.in',
#  'altnews.in',
#  'altnews.in',
#  'altnews.in',
#  'altnews.in',
#  'altnews.in',
#  'oneindia.com',
#  'oneindia.com',
#  'oneindia.com',
#  'oneindia.com',
#  'oneindia.com',
#  'indiatoday.in',
#  'thewirehindi.com',
#  'thewirehindi.com',
#  'thewirehindi.com',
#  'thewirehindi.com',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'aajtak.in',
#  'ndtv.com',
#  'ndtv.com',
#  'ndtv.com',
#  'ndtv.com',
#  'ndtv.com',
#  'ndtv.com',
#  'republicworld.com',
#  'republicworld.com',
#  'republicworld.com',
#  'republicworld.com',
#  'opindia.com',
#  'opindia.com',
#  'opindia.com',
#  'opindia.com',
#  'opindia.com',
#  'opindia.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'india.com',
#  'news18.com',
#  'news18.com',
#  'news18.com',
#  'news18.com',
#  'jagran.com',
#  'jagran.com',
#  'jagran.com',
#  'jagran.com',
#  'jagran.com',
#  'jagran.com',
#  'jagran.com',
#  'jagran.com',
#  'newsnationtv.com',
#  'tv9hindi.com',
#  'tv9hindi.com',
#  'abplive.com',
#  'abplive.com',
#  'abplive.com',
#  'abplive.com',
#  'abplive.com',
#  'abplive.com',
#  'telegraphindia.com',
#  'thewire.in',
#  'thehindu.com',
#  'thequint.com',
#  'lokmat.com',
#  'lokmat.com',
#  'ndtv.in',
#  'ndtv.in',
#  'ndtv.in',
#  'ndtv.in',
#  'tv9bharatvarsh.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'amarujala.com',
#  'doonhorizon.in',
#  'doonhorizon.in',
#  'loksatta.com',
#  'loksatta.com',
#  'timesnowhindi.com',
#  'dnaindia.com',
#  'satyahindi.com',
#  'nayaindia.com',
#  'nayaindia.com',
#  'nayaindia.com',
#  'panchjanya.com',
#  'panchjanya.com',
#  'indiatv.in',
#  'indiatv.in',
#  'mumbaitak.in',
#  'upuklive.com',
#  'upuklive.com',
#  'ichowk.in',
#  'ichowk.in',
#  'ichowk.in',
#  'jantaserishta.com',
#  'mpbreakingnews.in',
#  'mpbreakingnews.in',
#  'uptak.in',
#  'uptak.in']

# %%
for k in keywords2domain.keys():
    keywords2domain[k] = list(set(keywords2domain[k]))

# %% [markdown]
# ### build keyword network

# %%
nodes = defaultdict(int)
edges = defaultdict(int)
for k in keywords2domain.keys():
    domainlist = list(set(keywords2domain[k]))
    if len(domainlist) > 5:
        for i in range(len(domainlist)-1):
            if domainlist[i] not in nodes:
                nodes[domainlist[i]]+=1
            for j in range(i+1, len(domainlist)):
                edgepair = sorted([domainlist[i], domainlist[j]])
                edges[(edgepair[0], edgepair[1])]+=1
        
        nodes[domainlist[len(domainlist)-1]]+=1

# %%
import networkx as nx

G = nx.Graph()

# for n in nodes.keys():
#     G.add_node(n, size=nodes[n], value=domainvalues[n])

ndlist = []
    
for e in edges:
    if edges[e] > 50:
        if e[0] not in ndlist:            
            G.add_node(e[0], size=nodes[e[0]])
            ndlist.append(e[0])
        if e[1] not in ndlist:
            G.add_node(e[1], size=nodes[e[1]])
            ndlist.append(e[1])
        
        G.add_edge(e[0], e[1], weight=edges[e])

# %%
nx.write_gexf(G, "./Jan24_domainkeywords.gexf", encoding='utf-8')
